# %% [markdown]
# Tyler Beaulieu
# DS5010, Fall 2024
# October 24, 2024
#
# <h4 style="text-align:center;">Homework 6</h4>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b><p style="font-size: XX-large">Problem 1 (20 pts): Special Methods</p></b> </div>

# %% [markdown]
# 1.(3 pts) Create an "Order" class with 2 attributes: 1) amounts (int) and 2) numberOfItems (int). \_\_init__ method should take in 3 parameters: self, amounts, numberOfItems.\
# 2.(2 pts) Instantiate an object of this class and name it order1. Use [dir()](https://www.geeksforgeeks.org/python-dir-function/) function to list all default and custom properties of the class.\
# 3.(5 pts) Customize [\_\_str__](https://www.geeksforgeeks.org/str-vs-repr-in-python/) method so that when the object is printed, it should print out a short sentence about the order object with both attributes. For instance: `print(order1)` should output "This order amounts to $100 and contains 5 items". Print order1 object instantiated from question 2. \
# 4.(5 pts) Customize [\_\_gt__](https://www.geeksforgeeks.org/customize-your-python-class-with-magic-or-dunder-methods/) method. It should take in 2 parameters: self and other, and return a boolean denoting whether its amounts is greater than other's. Create another Order object, name it order2, and compare it order1 using ">" operator. For example, if order1 has amounts of 100 and order2 has amounts of 120, then order1>order2 should return False.\
# 5.(5 pts) Customize [\_\_len__](https://www.geeksforgeeks.org/customize-your-python-class-with-magic-or-dunder-methods/) method to return numberOfItems. Use len() to print out the number of items order1 has.

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b><p style="font-size: XX-large">Problem 2 and 3: Abstraction & Inheritance</p></b> </div>

# %% [markdown]
# Suppose you are a programmer and are given the following class diagram from Business Analysts and are asked to create the classes in python accordingly:
#
# ![Q2.png](attachment:7c52eba7-6a09-4e4b-b462-944b1067670f.png)
#
# In case you are not familiar with class diagrams, each "Box" represents a class and each class contains 3 sections:
# 1) Top Section - class name (eg. Animal)
# 2) Middle Section - attributes (eg. age)
# 3) Bottom Section - method (eg. isMammal())

# %% [markdown]
# ---

# %% [markdown]
# # Problem 2 (14 pts): Animals I: Abstraction
#
#
# 1.(2 pts) The "Animal" class is abstract, the rest are concrete. Concrete classes inherit from the abstract class. Please briefly explain in your own words the difference between abstract and concrete classes.\
# 2.(2 pts) Please explain in your own words what happens when a class inherits from another class.\
# 3.(10 pts) Create the abstract "Animal" class in a ipynb or python file with the attributes and methods shown above. Please note '+' means the attributes/methods are <strong>Public</strong> and '-' means they are <strong>Private</strong>.
#
# Please note, for full marks, be sure to follow the <strong>docString</strong> format and different naming standards for different access modifiers. For example, self.attribute and method() for public attributes and methods vs. self.\__attribute and \__method() for private attributes and methods. For all the method implementation, simply print a statement. For example, `print("It is a mammal")` suffices for IsMammal()

# %% [markdown]
# ---

# %% [markdown]
# # Problem 3 (26 pts): Animals II: Inheritance
#
# 1.(2 pts) Import the abstract "Animal" class from Problem 2 that is stored in another ipynb or python file. Hint: `%run AbstractClass.ipynb` or `from Module_name import ClassName` can help you access all the classes.\
# 2.(24 pts) Create the 3 concrete classes (Duck, Fish, Zebra). Instantiate 4 objects: 2 ducks (1 for each initialization method), 1 fish and 1 zebra. Call all the methods available to each object and print all 4 objects.
#
# Some things to note:\
# 1.Customize \_\_str__ method so that when the object is printed, it prints out all the attributes of the object. For example, when a duck object is printed, it should print: "This duck is 1 year old, is a male, and has yellow beak.\
# 2.Please note, for full marks, be sure to follow the <strong>docString</strong> format and different naming standards for different access modifiers.For example, self.attribute and method() for public attributes and methods vs. self.\__attribute and \__method() for private attributes and methods.

# %% [markdown]
# ------

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b><p style="font-size: XX-large">Problem 4 (10 pts): Polymorphism</p></b> </div>

# %% [markdown]
# Polymorphism refers to the concept that allows objects of different classes to be treated as objects of a common class. It enables objects of different classes to call a common method despite their different implementation of the method. \
# 1.(2 pts) Create an "Animal" class that has one abstract method: speak()\
# 2.(8 pts) Create "Cat" and "Dog" classes that inherit from the "Animal" class and implement the speak() method according to the behaviours of Cat and Dog respectively. It is enough to print out the sound that each makes when they are speaking. Create an object of each dog and cat class, and call their speak() methods. An example output: \
# ![Q4.png](attachment:28b17c2f-efc9-4cf1-a28a-ede537f69710.png)

# %% [markdown]
# ----

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b><p style="font-size: XX-large">Problem 5 (30 pts): Stores (Encapsulation)</p></b> </div>

# %% [markdown]
# Create a Store class in python that adds inventory and sells items. Store originally has a balance of $0 and zero inventory. This store only has 2 items: apple for 2 dollars and banana for 1 dollar. You can store the items and their prices in a dictionary, you cannot sell 7 apples when you only have 5 left in the inventory. Before selling items it should check inventory. You can also use a dictionary to keep track the inventory {item:quantity}. When adding inventory, make sure only add inventory key that exists in the dictionary. After selling items, inventory should be reduced and balance should be increased accordingly. It should also have methods that calculates the balance in  dollars and inventory in quantity.
#
# After the class is created, do the following operations:
#
# 1. Create the Store object
# 2. Add 10 apples, 5 bananas and 2 pears
# 3. Sell 3 apples and 7 bananas
# 4. Print balance and remaining inventory
#
# An example output:
#
# ![image.png](attachment:484324d2-116c-484a-b4e6-5fb0b2a48bbe.png)
#
# Please note all attributes and operations should be encapsulated in the object class. All parameters should be passed into the method calls.

# %% [markdown]
# ---

# %% [markdown]
# # Done!
